# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.linspace(0.01,1-0.01,1000)
y = -((1-a)/2 * np.log2(1-a) + (1+a)/2 * np.log2(1+a)-1)

# %%
plt.plot(a,y)
plt.xlabel(r"$|\vec{a}|$")
plt.ylabel("S")
plt.title("Entropy")
# Out:
# Text(0.5, 1.0, 'Entropy')
