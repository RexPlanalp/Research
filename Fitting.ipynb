1.35000000000000E+001, -7.40740748008986E-002,
1.36000000000000E+001, -7.35294123271650E-002,
1.37000000000000E+001, -7.29927011140120E-002,
1.38000000000000E+001, -7.24637683140021E-002,
1.39000000000000E+001, -7.19424460538059E-002,
1.40000000000000E+001, -7.14285712563560E-002,
1.41000000000000E+001, -7.09219854705902E-002,
1.42000000000000E+001, -7.04225347084032E-002,
1.43000000000000E+001, -6.99300692884728E-002,
1.44000000000000E+001, -6.94444436866094E-002,
1.45000000000000E+001, -6.89655163923328E-002,
1.46000000000000E+001, -6.84931497713706E-002,
1.47000000000000E+001, -6.80272099337878E-002,
1.48000000000000E+001, -6.75675666074942E-002,
1.49000000000000E+001, -6.71140930168668E-002,
1.50000000000000E+001, -1.77306784802070E-003]
x = []
y = []

for i in range(int(len(data)/2)-1):
    if i % 2 ==0:
        x.append(data[i])
    else:
        y.append(data[i])
xs = np.array(x)
ys = np.array(y)

xs = np.delete(xs,0)
ys = np.delete(ys,0)

# %%
#UNCOMMENT
def y(theta, x):
    return -1/(x+0.1) - np.exp(-theta[0]*x)/(x+0.1) - theta[1]*np.exp(-theta[2]*x)
#UNCOMMENT



def fun(theta):
    return y(theta, xs) - ys

theta0 = [0,0,0]
res1 = least_squares(fun, theta0,loss = "soft_l1")
tol = 1E-10
def SAE(x):
    return -1/(x+tol) - np.exp(-2.03929*x)/(x+tol) - 0.3953*np.exp(-6.1805*x)
print(res1.x)
# Out:
# [ 0.55098334 -0.05247243  0.00543331]

# %%
#xfull= np.linspace(0.1,15,100000)
#yfull = y(res1.x,xfull)
#plt.plot(xfull,SAE(xfull),label = "Brynn",linestyle = "dotted")
#plt.plot(xfull,yfull,label = "Rex",linestyle = "dashed")
#plt.plot(xs,ys,label = "Raw")
#plt.semilogy(xfull,-SAE(xfull),xfull,-yfull)
#plt.xlim([-0.1,6])
#plt.ylim([-10,0])
#print(res1.x)
#plt.title("Potential")
#plt.legend()
#plt.xlabel("r (au)")
#plt.ylabel("V (au)")

# %%
from scipy.linalg import eigvalsh
x = np.arange(0.001,10,0.001)

test = []


def Argon(grid):
    """ This is a simple SAE potential for helium with the centrifugal term of the potential added in spherical coordinate.
        z is not used but is included for uniformity with the Coulomb funcion"""
    return -1.0*np.power(grid, -1.0) + -17.0*np.exp(-0.8103*grid)/grid  - (-15.9583)*np.exp(-1.2305*grid)\
        - (-27.7467)*np.exp(-4.3946*grid) - (2.1768)*np.exp(-86.7179*grid) 
    
V3 = Argon(x)
V1 = SAE(x)
V2 = y(res1.x,x)

def Eigval(V):
    global x 
    dx = x[1]-x[0]
    t = -1/(2*dx**2)

    d_0 = V-5*t/2
    d_1 = 4*t/3 * np.ones(len(x)-1)
    d_2 = -t/12 * np.ones(len(x)-2)
    A = np.diag(d_0,k=0)+np.diag(d_1,k=1)+np.diag(d_1,k=-1)+np.diag(d_2,k=2)+np.diag(d_2,k=-2)
    E = eigvalsh(A)
    return (E[0:8])
#test.append(Eigval(V1))
#test.append(Eigval(V2))
energies = Eigval(V2)
for i in energies:
    print(i)
# Out:
# -0.8693270372561424
# -0.11523487576273582
# 0.084996416083194
# 0.38281703152037627
# 0.7944415755515676
# 1.3134359432875031
# 1.9366612318515317
# 2.6624117209094296

# %%
plt.plot(x,SAE(x))
plt.plot(x,ArSAE(x))

  6.55000000000000E+000, -1.60701375877631E-001,
  6.60000000000000E+000, -1.59332263604671E-001,
  6.65000000000000E+000, -1.57986625158624E-001,
  6.70000000000000E+000, -1.56663868976210E-001,
  6.75000000000000E+000, -1.55363417244918E-001,
  6.80000000000000E+000, -1.54084714900726E-001,
  6.85000000000000E+000, -1.52827218869025E-001,
  6.90000000000000E+000, -1.51590407183799E-001,
  6.95000000000000E+000, -1.50373768126391E-001,
  7.00000000000000E+000, -1.49176810445820E-001,
  7.05000000000000E+000, -1.47999051373541E-001,
  7.10000000000000E+000, -1.46840026471375E-001,
  7.15000000000000E+000, -1.45699280230561E-001,
  7.20000000000000E+000, -1.44576372770393E-001,
  7.25000000000000E+000, -1.43470872833556E-001,
  7.30000000000000E+000, -1.42382363733660E-001,
  7.35000000000000E+000, -1.41310435045051E-001,
  7.40000000000000E+000, -1.40254691848563E-001,
  7.45000000000000E+000, -1.39214742574098E-001,
  7.50000000000000E+000, -1.38190211677556E-001,
  7.55000000000000E+000, -1.37180724289717E-001,
  7.60000000000000E+000, -1.36185921987401E-001,
  7.65000000000000E+000, -1.35205445083966E-001,
  7.70000000000000E+000, -1.34238949040890E-001,
  7.75000000000000E+000, -1.33286089056218E-001,
  7.80000000000000E+000, -1.32346531468184E-001,
  7.85000000000000E+000, -1.31419940002977E-001,
  7.90000000000000E+000, -1.30505992942336E-001,
  7.95000000000000E+000, -1.29604362436888E-001,
  8.00000000000000E+000, -1.28714731636658E-001,
  8.05000000000000E+000, -1.27836776384930E-001,
  8.10000000000000E+000, -1.26970181176283E-001,
  8.15000000000000E+000, -1.26114621816129E-001,
  8.20000000000000E+000, -1.25269778105467E-001,
  8.25000000000000E+000, -1.24435319068355E-001,
  8.30000000000000E+000, -1.23610910586659E-001,
  8.35000000000000E+000, -1.22796200982691E-001,
  8.40000000000000E+000, -1.21990828440738E-001,
  8.45000000000000E+000, -1.21194403180891E-001,
  8.50000000000000E+000, -1.20406507534216E-001,
  8.55000000000000E+000, -1.19626674964832E-001,
  8.60000000000000E+000, -1.18854384232645E-001,
  8.65000000000000E+000, -1.18089017816690E-001,
  8.70000000000000E+000, -1.17329814530050E-001,
  8.75000000000000E+000, -1.16575792632356E-001,
  8.80000000000000E+000, -1.15825659261535E-001,
  8.85000000000000E+000, -1.15077188541486E-001,
  8.90000000000000E+000, -1.14327158992022E-001,
  8.95000000000000E+000, -1.13553802619235E-001,
  9.00000000000000E+000, -1.12797799106621E-001]
x = []
y = []

for i in range(int(len(argon_data)/2)-1):
    if i % 2 ==0:
        x.append(argon_data[i])
    else:
        y.append(argon_data[i])
xs = np.array(x)
ys = np.array(y)

xs = np.delete(xs,[0])
ys = np.delete(ys,[0])

# %%
tol = 0.01
def y(theta, x):
    global tol 
    return -1/(x+tol) - np.exp(-theta[0]*x)/(x+tol) - theta[1]*np.exp(-theta[2]*x) - theta[3]*np.exp(-theta[4]*x) -\
    - theta[5]*np.exp(-theta[6]*x)


def fun(theta):
    return y(theta, xs) - ys

theta0 = [0,0,0,0,0,0,0]
res1 = least_squares(fun, theta0,loss = "linear",method = "lm")



print(res1.x)
# Out:
# [ 3.82460041e-01  3.71732555e+01  3.02943211e+00  2.18735327e+06
#   1.95739683e+02 -2.54145433e+02  1.17170981e+01]
